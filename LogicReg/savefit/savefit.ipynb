# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

# %% [markdown]
# ## savefit 1

# %%
root = 'C:/Users/asus/Desktop/CSC4050/LogicReg/R/savefit/'
tree1 = pd.read_csv(root+'savefit1_tree1.csv')
tree1 = tree1.values
tree2 = pd.read_csv(root+'savefit1_tree2.csv')
tree2 = tree2.values

response = pd.read_csv(root+'savefit1_response.csv')
response = response.values.squeeze()

censor = pd.read_csv(root+'savefit1_censor.csv')
censor = censor.values.squeeze()

weight = pd.read_csv(root+'savefit1_weight.csv')
weight = weight.values.squeeze()

binary = pd.read_csv(root+'savefit1_binary.csv', header=None, skiprows=[0])
binary = binary.values

# %%
logreg_savefit1 = {
    'class': 'logreg',
    'nsample': 500,
    'nbinary': 20,
    'nseparate': 0,
    'type': 'regression',
    'select': 'single.model',
    'anneal.control':{
        'start': -1,
        'end': -4,
        'iter': 25000,
        'earlyout': 0,
        'update': 1000,
    },
    'tree.control': {
        'treesize': 8,
        'opers': 1,
        'minmass': 0,
        'operators': 'both',
    },
    'seed': 0,
    'choice': 1,
    'nleaves': -1,
    'ntrees': 2,
    'penalty': 0,
    'response': response, # double[500] 
    'binary':  binary, # double[500*20]: 0 or 1
    'separate': 0, 
    'censor': censor, # double[500]
    'weight': weight, # double[500]
    'model': {
        'class': 'logregmodel',
        'ntrees': np.array([2, 2]), # dtype=np.float64
        'nleaves': np.array([-1, -1]), # dtype=np.float64
        'score': np.array([0.966493], dtype=np.float64),
        'coef': np.array([1.982887, -1.304364, 2.153445], dtype=np.float64),
        'trees': [
            {
                'class': 'logregtree',
                'whichtree': 1,
                'coef': np.array([-1.304364], dtype=np.float64),
                'trees': tree1, # A data.frame with 15 rows and columns(number,conc,knot,neg,pick)
            },
            {
                'class': 'logregtree',
                'whichtree': 2,
                'coef': np.array([2.153445], dtype=np.float64),
                'trees': tree2, # A data.frame with 15 rows and columns(number,conc,knot,neg,pick)
            },
        ]
    },
    # 'call': {
    #     'func': logreg,
    #     'args': {
    #         'resp': logreg_testdat[:,0],
    #         'bin': logreg_testdat[:,1:21],
    #         'type': 2,
    #         'select': 1,
    #         'ntrees': 2,
    #         'anneal_control': myanneal,
    #     }
    # }
}

# # apply 'call'
# logreg_savefit1['call']['func'](**logreg_savefit1['call']['args'])

# %% [markdown]
# ## savefit 2

# %%
root = 'C:/Users/asus/Desktop/CSC4050/LogicReg/R/savefit/'
# response
response = pd.read_csv(root+'savefit2_response.csv')
response = response.values.squeeze()
# censor
censor = pd.read_csv(root+'savefit2_censor.csv')
censor = censor.values.squeeze()
# weight
weight = pd.read_csv(root+'savefit2_weight.csv')
weight = weight.values.squeeze()
# binary
binary = pd.read_csv(root+'savefit2_binary.csv', header=None, skiprows=[0])
binary = binary.values
# allscores
allscores = pd.read_csv(root+'savefit2_allscores.csv', header=None, skiprows=[0])
allscores = allscores.values
# tree1_1
tree1_1 = pd.read_csv(root+'savefit2_tree1_1.csv')
tree1_1 = tree1_1.values
# tree2_1
tree2_1 = pd.read_csv(root+'savefit2_tree2_1.csv')
tree2_1 = tree2_1.values
# tree3_1
tree3_1 = pd.read_csv(root+'savefit2_tree3_1.csv')
tree3_1 = tree3_1.values
# tree4_1
tree4_1 = pd.read_csv(root+'savefit2_tree4_1.csv')
tree4_1 = tree4_1.values
# tree5_1
tree5_1 = pd.read_csv(root+'savefit2_tree5_1.csv')
tree5_1 = tree5_1.values
# tree6_1
tree6_1 = pd.read_csv(root+'savefit2_tree6_1.csv')
tree6_1 = tree6_1.values
# tree7_1
tree7_1 = pd.read_csv(root+'savefit2_tree7_1.csv')
tree7_1 = tree7_1.values
# tree8_1 & tree8_2
tree8_1 = pd.read_csv(root+'savefit2_tree8_1.csv')
tree8_1 = tree8_1.values
tree8_2 = pd.read_csv(root+'savefit2_tree8_2.csv')
tree8_2 = tree8_2.values
# tree9_1 & tree9_2
tree9_1 = pd.read_csv(root+'savefit2_tree9_1.csv')
tree9_1 = tree9_1.values
tree9_2 = pd.read_csv(root+'savefit2_tree9_2.csv')
tree9_2 = tree9_2.values
# tree10_1 & tree10_2
tree10_1 = pd.read_csv(root+'savefit2_tree10_1.csv')
tree10_1 = tree10_1.values
tree10_2 = pd.read_csv(root+'savefit2_tree10_2.csv')
tree10_2 = tree10_2.values
# tree11_1 & tree11_2
tree11_1 = pd.read_csv(root+'savefit2_tree11_1.csv')
tree11_1 = tree11_1.values
tree11_2 = pd.read_csv(root+'savefit2_tree11_2.csv')
tree11_2 = tree11_2.values
# tree12_1 & tree12_2
tree12_1 = pd.read_csv(root+'savefit2_tree12_1.csv')
tree12_1 = tree12_1.values
tree12_2 = pd.read_csv(root+'savefit2_tree12_2.csv')
tree12_2 = tree12_2.values
# tree13_1 & tree13_2
tree13_1 = pd.read_csv(root+'savefit2_tree13_1.csv')
tree13_1 = tree13_1.values
tree13_2 = pd.read_csv(root+'savefit2_tree13_2.csv')
tree13_2 = tree13_2.values

# %%
logreg_savefit2 = {
    'class': 'logreg',
    'nsample': 500,
    'nbinary': 20,
    'nseparate': 0,
    'type': 'regression',
    'select': 'multiple.models',
    'anneal.control':{
        'start': -1,
        'end': -4,
        'iter': 25000,
        'earlyout': 0,
        'update': 0,
    },
    'tree.control': {
        'treesize': 8,
        'opers': 1,
        'minmass': 0,
        'operators': 'both',
    },
    'seed': 0,
    'choice': 2,
    'nleaves': np.array([1, 7]),
    'ntrees': np.array([1, 2]),
    'penalty': 0,
    'response': response, # double[500] 
    'binary':  binary, # double[500*20]: 0 or 1
    'separate': 0, 
    'censor': censor, # double[500]
    'weight': weight, # double[500]
    'nmodels': 13,
    'alltrees':[
        { #1
            'class': 'logregmodel',
            'score': np.array([1.150024], dtype=np.float64),
            'nleaves': 1,
            'ntrees': 1,
            'coef': np.array([3.788337, -1.911510], dtype=np.float64),
            'trees': [
                {
                    'class': 'logregtree',
                    'whichtree': 1,
                    'coef': np.array([-1.91151], dtype=np.float64),
                    'trees': tree1_1,
                }
            ]
        },
        { #2
            'class': 'logregmodel',
            'score': np.array([1.048063], dtype=np.float64),
            'nleaves': 2,
            'ntrees': 1,
            'coef': np.array([1.867157, 2.131689], dtype=np.float64),
            'trees': [
                {
                    'class': 'logregtree',
                    'whichtree': 1,
                    'coef': np.array([2.131689], dtype=np.float64),
                    'trees': tree2_1,
                }
            ]            
        },
        { #3
            'class': 'logregmodel',
            'score': np.array([1.045656], dtype=np.float64),
            'nleaves': 3,
            'ntrees': 1,
            'coef': np.array([1.852558, 2.135427], dtype=np.float64),
            'trees': [
                {
                    'class': 'logregtree',
                    'whichtree': 1,
                    'coef': np.array([2.135427], dtype=np.float64),
                    'trees': tree3_1,
                }
            ]            
        },    
        { #4
            'class': 'logregmodel',
            'score': np.array([1.042086], dtype=np.float64),
            'nleaves': 4,
            'ntrees': 1,
            'coef': np.array([1.857468, 2.142993], dtype=np.float64),
            'trees': [
                {
                    'class': 'logregtree',
                    'whichtree': 1,
                    'coef': np.array([2.142993], dtype=np.float64),
                    'trees': tree4_1,
                }
            ]            
        },    
        { #5
            'class': 'logregmodel',
            'score': np.array([1.042086], dtype=np.float64),
            'nleaves': 5,
            'ntrees': 1,
            'coef': np.array([1.857468, 2.142993], dtype=np.float64),
            'trees': [
                {
                    'class': 'logregtree',
                    'whichtree': 1,
                    'coef': np.array([2.142993], dtype=np.float64),
                    'trees': tree5_1,
                }
            ]            
        }, 
        { #6
            'class': 'logregmodel',
            'score': np.array([1.042086], dtype=np.float64),
            'nleaves': 6,
            'ntrees': 1,
            'coef': np.array([4.000461, -2.142993], dtype=np.float64),
            'trees': [
                {
                    'class': 'logregtree',
                    'whichtree': 1,
                    'coef': np.array([-2.142993], dtype=np.float64),
                    'trees': tree6_1,
                }
            ]            
        },     
        { #7
            'class': 'logregmodel',
            'score': np.array([1.040085], dtype=np.float64),
            'nleaves': 7,
            'ntrees': 1,
            'coef': np.array([1.838969, 2.145768], dtype=np.float64),
            'trees': [
                {
                    'class': 'logregtree',
                    'whichtree': 1,
                    'coef': np.array([2.145768], dtype=np.float64),
                    'trees': tree7_1,
                }
            ]            
        },   
        { #8
            'class': 'logregmodel',
            'score': np.array([1.116847], dtype=np.float64),
            'nleaves': 2,
            'ntrees': 2,
            'coef': np.array([1.9841336,  1.8898510, -0.9044408], dtype=np.float64),
            'trees': [
                {
                    'class': 'logregtree',
                    'whichtree': 1,
                    'coef': np.array([1.889851], dtype=np.float64),
                    'trees': tree8_1,
                },
                {
                    'class': 'logregtree',
                    'whichtree': 2,
                    'coef': np.array([-0.9044408], dtype=np.float64),
                    'trees': tree8_2,
                }                
            ]            
        },    
        { #9
            'class': 'logregmodel',
            'score': np.array([1.033328], dtype=np.float64),
            'nleaves': 3,
            'ntrees': 2,
            'coef': np.array([1.5814508, 0.4009104, 2.1288736], dtype=np.float64),
            'trees': [
                {
                    'class': 'logregtree',
                    'whichtree': 1,
                    'coef': np.array([0.4009104], dtype=np.float64),
                    'trees': tree9_1,
                },
                {
                    'class': 'logregtree',
                    'whichtree': 2,
                    'coef': np.array([2.128874], dtype=np.float64),
                    'trees': tree9_2,
                }                
            ]            
        },    
        { #10
            'class': 'logregmodel',
            'score': np.array([0.9884828], dtype=np.float64),
            'nleaves': 4,
            'ntrees': 2,
            'coef': np.array([4.115110, -1.111488, -2.115937], dtype=np.float64),
            'trees': [
                {
                    'class': 'logregtree',
                    'whichtree': 1,
                    'coef': np.array([-1.111488], dtype=np.float64),
                    'trees': tree10_1,
                },
                {
                    'class': 'logregtree',
                    'whichtree': 2,
                    'coef': np.array([-2.115937], dtype=np.float64),
                    'trees': tree10_2,
                }                
            ]            
        }, 
        { #11
            'class': 'logregmodel',
            'score': np.array([0.9823242], dtype=np.float64),
            'nleaves': 5,
            'ntrees': 2,
            'coef': np.array([0.7695563, 1.2242470, 2.1228569], dtype=np.float64),
            'trees': [
                {
                    'class': 'logregtree',
                    'whichtree': 1,
                    'coef': np.array([1.224247], dtype=np.float64),
                    'trees': tree11_1,
                },
                {
                    'class': 'logregtree',
                    'whichtree': 2,
                    'coef': np.array([2.122857], dtype=np.float64),
                    'trees': tree11_2,
                }                
            ]            
        },    
        { #12
            'class': 'logregmodel',
            'score': np.array([0.979187], dtype=np.float64),
            'nleaves': 6,
            'ntrees': 2,
            'coef': np.array([0.7643575, 2.1331084, 1.2300457], dtype=np.float64),
            'trees': [
                {
                    'class': 'logregtree',
                    'whichtree': 1,
                    'coef': np.array([2.133108], dtype=np.float64),
                    'trees': tree12_1,
                },
                {
                    'class': 'logregtree',
                    'whichtree': 2,
                    'coef': np.array([1.230046], dtype=np.float64),
                    'trees': tree12_2,
                }                
            ]            
        },  
        { #13
            'class': 'logregmodel',
            'score': np.array([0.9778322], dtype=np.float64),
            'nleaves': 7,
            'ntrees': 2,
            'coef': np.array([1.990380,  2.132266, -1.286450], dtype=np.float64),
            'trees': [
                {
                    'class': 'logregtree',
                    'whichtree': 1,
                    'coef': np.array([2.132266], dtype=np.float64),
                    'trees': tree13_1,
                },
                {
                    'class': 'logregtree',
                    'whichtree': 2,
                    'coef': np.array([-1.28645], dtype=np.float64),
                    'trees': tree13_2,
                }                
            ]            
        },         
    ],
    'allscores': allscores, # double[13*3]
    # 'call': {
    #     'func': logreg,
    #     'args': {
    #         'resp': logreg_testdat[:,0],
    #         'bin': logreg_testdat[:,1:21],
    #         'type': 2,
    #         'select': 2,
    #         'ntrees': [1, 2],
    #         'nleaves': [1, 7],
    #         'anneal_control': myanneal2,
    #     }
    # }
}

# %% [markdown]
# ## savefit 3

# %%
root = 'C:/Users/asus/Desktop/CSC4050/LogicReg/R/savefit/'
# response
response = pd.read_csv(root+'savefit3_response.csv')
response = response.values.squeeze()
# binary
binary = pd.read_csv(root+'savefit3_binary.csv', header=None, skiprows=[0])
binary = binary.values
# censor
censor = pd.read_csv(root+'savefit3_censor.csv')
censor = censor.values.squeeze()
# weight
weight = pd.read_csv(root+'savefit3_weight.csv')
weight = weight.values.squeeze()
# cvscores
cvscores = pd.read_csv(root+'savefit3_cvscores.csv', header=None, skiprows=[0])
cvscores = cvscores.values

# %%
logreg_savefit3 = {
    'class': 'logreg',
    'nsample': 500,
    'nbinary': 20,
    'nseparate': 0,
    'type': 'regression',
    'select': 'cross.validation',
    'anneal.control':{
        'start': -1,
        'end': -4,
        'iter': 25000,
        'earlyout': 0,
        'update': 0,
    },
    'tree.control': {
        'treesize': 8,
        'opers': 1,
        'minmass': 0,
        'operators': 'both',
    },
    'seed': 0,
    'choice': 3,
    'nleaves': np.array([1, 7]),
    'ntrees': np.array([1, 2]),
    'kfold': 10,
    'response': response, # double[500] 
    'binary':  binary, # double[500*20]: 0 or 1
    'separate': 0, 
    'censor': censor, # double[500]
    'weight': weight, # double[500]
    'cvscores': cvscores, # df 130*8 [ntree,nleaf,k,kfold,train, train.ave, test, test.ave]
    
    # 'call': {
    #     'func': logreg,
    #     'args': {
    #         'resp': logreg_testdat[:,0],
    #         'bin': logreg_testdat[:,1:21],
    #         'type': 2,
    #         'select': 3,
    #         'ntrees': np.array([1,2]),
    #         'nleaves': np.array([1,7]),
    #         'anneal_control': myanneal2,
    #     }
    # }
}

# %% [markdown]
# ## savefit 4

# %%
root4='C:/Users/WONDERCHEN/Desktop/DDA/savefit/'
response4 = pd.read_csv(root4 + 'savefit4_response.csv',header=None, skiprows=[0])
response4 = response4.values[:,1]
binary4 = pd.read_csv(root4 + 'savefit4_binary.csv',header=None, skiprows=[0])
binary4 = binary4.values[:,1:]
censor4 = pd.read_csv(root4 + 'savefit4_censor.csv')
censor4 = censor4.values[:,1]
weight4 = pd.read_csv(root4 + 'savefit4_weight.csv')
weight4 = weight4.values[:,1]
randscore4 = pd.read_csv(root4 + 'savefit4_randscore.csv')
randscore4 = randscore4.values[:,1]

# %%
logreg_savefit4 = {
    'class': 'logreg',
    'nsample': 500,
    'nbinary': 20,
    'nseparate': 0,
    'type': 'regression',
    'select': 'null.model.test',
    'anneal.control':{
        'start': -1,
        'end': -4,
        'iter': 25000,
        'earlyout': 0,
        'update': 0,
    },
    'tree.control': {
        'treesize': 8,
        'opers': 1,
        'minmass': 0,
        'operators': 'both',
    },
    'seed': 0,
    'choice': 3,
    'nleaves': -1, #np.array([-1])
    'ntrees':2, #np.array([2])
    'nrep':25, #np.array([25])
    'response':response4,
    'binary':binary4,
    'separate':0,
    'censor':censor4,
    'weight':weight4,
    'nullscore':1.494099,
    'bestscore':0.9689451,
    'randscore':randscore4,
    
    # 'call': {
    #     'func': logreg,
    #     'args': {
    #         'resp': logreg_testdat[:,0],
    #         'bin': logreg_testdat[:,1:21],
    #         'type': 2,
    #         'select': 4,
    #         'ntrees': 2,
    #         'anneal_control': myanneal2,
    #     }
    # }
}

# %% [markdown]
# ## savefit 5

# %%
root5='C:/Users/WONDERCHEN/Desktop/DDA/savefit/'
response5 = pd.read_csv(root5 + 'savefit5_response.csv')
response5 = response5.values[:,1]
binary5 = pd.read_csv(root5 + 'savefit5_binary.csv',header=None, skiprows=[0])
binary5 = binary5.values[:,1:]
censor5 = pd.read_csv(root5 + 'savefit5_censor.csv')
censor5 = censor5.values[:,1]
weight5 = pd.read_csv(root5 + 'savefit5_weight.csv')
weight5 = weight5.values[:,1]
allscores5 = pd.read_csv(root5 + 'savefit5_allscores.csv')
allscores5 = allscores5.values[:,1:]
randscores5 = pd.read_csv(root5 + 'savefit5_randscores.csv',header=None, skiprows=[0])
randscores5 = randscores5.values[:,1:] ## row1=ntrees,row2=nleaf, colname=(x1,x2,...)

# %%
logreg_savefit5 = {
    'class': 'logreg',
    'nsample': 500,
    'nbinary': 20,
    'nseparate': 0,
    'type': 'regression',
    'select': 'randomization.test',
    'anneal.control':{
        'start': -1,
        'end': -4,
        'iter': 25000,
        'earlyout': 0,
        'update': 0,
    },
    'tree.control': {
        'treesize': 8,
        'opers': 1,
        'minmass': 0,
        'operators': 'both',
    },
    'seed': 0,
    'choice':5,
    'nleaves': np.array([1,7]),
    'ntrees':np.array([1,2]),
    'nrep':25, #np.array([25])
    'response':response5,
    'binary':binary5,
    'separate':0,
    'censor':censor5,
    'weight':weight5,
    'nullscore':1.494099,
    'bestscore':0.9707544,
    'randscores':randscores5,
    'allscores': allscores5
    
    # 'call': {
    #     'func': logreg,
    #     'args': {
    #         'resp': logreg_testdat[:,0],
    #         'bin': logreg_testdat[:,1:21],
    #         'type': 2,
    #         'select': 5,
    #         'ntrees': np.array([1,2]),
    #         'nleaves': np.array([1,7])
    #         'anneal_control': myanneal2,
    #     }
    # }
}

# %% [markdown]
# ## savefit 6

# %%
root = 'C:/Users/asus/Desktop/CSC4050/LogicReg/R/savefit/'
# response
response = pd.read_csv(root+'savefit6_response.csv')
response = response.values.squeeze()
# binary
binary = pd.read_csv(root+'savefit6_binary.csv', header=None, skiprows=[0])
binary = binary.values
# censor
censor = pd.read_csv(root+'savefit6_censor.csv')
censor = censor.values.squeeze()
# weight
weight = pd.read_csv(root+'savefit6_weight.csv')
weight = weight.values.squeeze()
# allscores
allscores = pd.read_csv(root+'savefit6_allscores.csv', header=None, skiprows=[0])
allscores = allscores.values
# tree1_1 & tree1_2
tree1_1 = pd.read_csv(root+'savefit6_tree1_1.csv')
tree1_1 = tree1_1.values
tree1_2 = pd.read_csv(root+'savefit6_tree1_2.csv')
tree1_2 = tree1_2.values
# tree2_1 & tree2_2
tree2_1 = pd.read_csv(root+'savefit6_tree2_1.csv')
tree2_1 = tree2_1.values
tree2_2 = pd.read_csv(root+'savefit6_tree2_2.csv')
tree2_2 = tree2_2.values
# tree3_1 & tree3_2
tree3_1 = pd.read_csv(root+'savefit6_tree3_1.csv')
tree3_1 = tree3_1.values
tree3_2 = pd.read_csv(root+'savefit6_tree3_2.csv')
tree3_2 = tree3_2.values
# tree4_1 & tree4_2
tree4_1 = pd.read_csv(root+'savefit6_tree4_1.csv')
tree4_1 = tree4_1.values
tree4_2 = pd.read_csv(root+'savefit6_tree4_2.csv')
tree4_2 = tree4_2.values
# tree5_1 & tree5_2
tree5_1 = pd.read_csv(root+'savefit6_tree5_1.csv')
tree5_1 = tree5_1.values
tree5_2 = pd.read_csv(root+'savefit6_tree5_2.csv')
tree5_2 = tree5_2.values
# tree6_1 & tree6_2
tree6_1 = pd.read_csv(root+'savefit6_tree6_1.csv')
tree6_1 = tree6_1.values
tree6_2 = pd.read_csv(root+'savefit6_tree6_2.csv')
tree6_2 = tree6_2.values
# tree7_1 & tree7_2
tree7_1 = pd.read_csv(root+'savefit6_tree7_1.csv')
tree7_1 = tree7_1.values
tree7_2 = pd.read_csv(root+'savefit6_tree7_2.csv')
tree7_2 = tree7_2.values
# tree8_1 & tree8_2
tree8_1 = pd.read_csv(root+'savefit6_tree8_1.csv')
tree8_1 = tree8_1.values
tree8_2 = pd.read_csv(root+'savefit6_tree8_2.csv')
tree8_2 = tree8_2.values

# %%
logreg_savefit2 = {
    'class': 'logreg',
    'nsample': 500,
    'nbinary': 20,
    'nseparate': 0,
    'type': 'regression',
    'select': 'greedy',
    'anneal.control':{
        'start': -1,
        'end': -4,
        'iter': 25000,
        'earlyout': 0,
        'update': 0,
    },
    'tree.control': {
        'treesize': 8,
        'opers': 1,
        'minmass': 0,
        'operators': 'both',
    },
    'seed': 0,
    'choice': 6,
    'nleaves': np.array([1, 12]),
    'ntrees': np.array([2, 2]),
    'response': response, # double[500] 
    'binary':  binary, # double[500*20]: 0 or 1
    'separate': 0, 
    'censor': censor, # double[500]
    'weight': weight, # double[500]
    'nmodels': 8,
    'alltrees':[
        { #1
            'class': 'logregmodel',
            'score': np.array([1.494099], dtype=np.float64),
            'nleaves': 0,
            'ntrees': 2,
            'coef': np.array([2.886104, 0.000000, 0.000000], dtype=np.float64),
            'trees': [
                {
                    'class': 'logregtree',
                    'whichtree': 1,
                    'coef': np.array([0]),
                    'trees': tree1_1,
                },
                {
                    'class': 'logregtree',
                    'whichtree': 2,
                    'coef': np.array([0]),
                    'trees': tree1_2,
                },                
            ]
        },
        { #2
            'class': 'logregmodel',
            'score': np.array([1.150024], dtype=np.float64),
            'nleaves': 1,
            'ntrees': 2,
            'coef': np.array([3.788337, -1.911510,  0.000000], dtype=np.float64),
            'trees': [
                {
                    'class': 'logregtree',
                    'whichtree': 1,
                    'coef': np.array([-1.91151], dtype=np.float64),
                    'trees': tree2_1,
                },
                {
                    'class': 'logregtree',
                    'whichtree': 2,
                    'coef': np.array([0]),
                    'trees': tree2_2,
                },
            ]            
        },
        { #3
            'class': 'logregmodel',
            'score': np.array([1.048063], dtype=np.float64),
            'nleaves': 2,
            'ntrees': 2,
            'coef': np.array([3.998846, -2.131689,  0.000000], dtype=np.float64),
            'trees': [
                {
                    'class': 'logregtree',
                    'whichtree': 1,
                    'coef': np.array([-2.131689], dtype=np.float64),
                    'trees': tree3_1,
                },
                {
                    'class': 'logregtree',
                    'whichtree': 2,
                    'coef': np.array([0], dtype=np.float64),
                    'trees': tree3_2,
                },
            ]            
        },    
        { #4
            'class': 'logregmodel',
            'score': np.array([1.033329], dtype=np.float64),
            'nleaves': 3,
            'ntrees': 2,
            'coef': np.array([3.7103243, -2.1288736,  0.4009104], dtype=np.float64),
            'trees': [
                {
                    'class': 'logregtree',
                    'whichtree': 1,
                    'coef': np.array([-2.128874], dtype=np.float64),
                    'trees': tree4_1,
                },
                {
                    'class': 'logregtree',
                    'whichtree': 2,
                    'coef': np.array([0.4009104], dtype=np.float64),
                    'trees': tree4_2,
                }
            ]            
        },    
        { #5
            'class': 'logregmodel',
            'score': np.array([0.9884828], dtype=np.float64),
            'nleaves': 4,
            'ntrees': 2,
            'coef': np.array([3.003622, -2.115937,  1.111488], dtype=np.float64),
            'trees': [
                {
                    'class': 'logregtree',
                    'whichtree': 1,
                    'coef': np.array([-2.115937], dtype=np.float64),
                    'trees': tree5_1,
                },
                {
                    'class': 'logregtree',
                    'whichtree': 2,
                    'coef': np.array([1.111488], dtype=np.float64),
                    'trees': tree5_2,
                }
            ]            
        }, 
        { #6
            'class': 'logregmodel',
            'score': np.array([0.9823242], dtype=np.float64),
            'nleaves': 5,
            'ntrees': 2,
            'coef': np.array([2.892413, -2.122857, 1.224247], dtype=np.float64),
            'trees': [
                {
                    'class': 'logregtree',
                    'whichtree': 1,
                    'coef': np.array([-2.122857], dtype=np.float64),
                    'trees': tree6_1,
                },
                {
                    'class': 'logregtree',
                    'whichtree': 2,
                    'coef': np.array([1.224247], dtype=np.float64),
                    'trees': tree6_2,
                }
            ]            
        },     
        { #7
            'class': 'logregmodel',
            'score': np.array([0.981351], dtype=np.float64),
            'nleaves': 6,
            'ntrees': 2,
            'coef': np.array([3.987984, -2.135427, 0.000000], dtype=np.float64),
            'trees': [
                {
                    'class': 'logregtree',
                    'whichtree': 1,
                    'coef': np.array([-2.135427], dtype=np.float64),
                    'trees': tree7_1,
                },
                {
                    'class': 'logregtree',
                    'whichtree': 2,
                    'coef': np.array([0], dtype=np.float64),
                    'trees': tree7_2,
                }
            ]            
        },   
        { #8
            'class': 'logregmodel',
            'score': np.array([0.9802507], dtype=np.float64),
            'nleaves': 7,
            'ntrees': 2,
            'coef': np.array([0,  0, 0], dtype=np.float64),
            'trees': [
                {
                    'class': 'logregtree',
                    'whichtree': 1,
                    'coef': np.array([0], dtype=np.float64),
                    'trees': tree8_1,
                },
                {
                    'class': 'logregtree',
                    'whichtree': 2,
                    'coef': np.array([0], dtype=np.float64),
                    'trees': tree8_2,
                }                
            ]            
        },           
    ],
    'allscores': allscores, # double[8*3]
    # 'call': {
    #     'func': logreg,
    #     'args': {
    #         'select': 6,
    #         'ntrees': 2,
    #         'nleaves': np.array([1, 12]),
    #         'oldfit': logreg_savefit1,
    #     }
    # }
}

# %% [markdown]
# ## savefit 7

# %%
root = 'C:/Users/asus/Desktop/CSC4050/LogicReg/R/savefit/'
# size
size = pd.read_csv(root+'savefit7_size.csv', header=None, skiprows=[0])
size = size.values
# single
single = pd.read_csv(root+'savefit7_single.csv')
single = single.values.squeeze()
# double
double = pd.read_csv(root+'savefit7_double.csv', header=None, skiprows=[0])
double = double.values
# triple
triple = pd.read_csv(root+'savefit7_triple.csv', header=None, skiprows=[0])
triple = triple.to_numpy()
triple = np.reshape(triple, (20, 20, 20))
triple = np.transpose(triple, axes=(0, 2, 1))
# response
response = pd.read_csv(root+'savefit7_response.csv')
response = response.values.squeeze()
# binary
binary = pd.read_csv(root+'savefit7_binary.csv', header=None, skiprows=[0])
binary = binary.values
# censor
censor = pd.read_csv(root+'savefit7_censor.csv')
censor = censor.values.squeeze()
# weight
weight = pd.read_csv(root+'savefit7_weight.csv')
weight = weight.values.squeeze()

# %%
logreg_savefit7 = {
    'class': 'logreg',
    'nsample': 500,
    'nbinary': 20,
    'nseparate': 0,
    'type': 'regression',
    'select': 'bayesian',
    'tree.control': {
        'treesize': 8,
        'opers': 1,
        'minmass': 0,
        'operators': 'both',
    },
    'seed': 0,
    'choice': 7,
    'size': size, # df [14*2]
    'single': single, # double[20]
    'mc.control': {
        'nburn': 1000,
        'niter': 1e+05,
        'hyperpars': np.array([0.6931472, 0.0000000, 0.0000000, 0.0000000], dtype=np.float64),
        'update': 0,
        'output': 4
    },
    'double': double, # double[20*20]
    'triple': triple, #integer[20*20*20]
    'nleaves': np.array([-1,-1]),
    'ntrees': np.array([2, 2]),
    'response': response, # double[500] 
    'binary':  binary, # double[500*20]: 0 or 1
    'separate': 0, 
    'censor': censor, # double[500]
    'weight': weight, # double[500]
    # 'call': {
    #     'func': logreg,
    #     'args': {
    #         'select': 7,
    #         'oldfit': logreg_savefit1,
    #         'mc.control': {
    #             'func': logreg_mc_control,
    #             'args': {
    #                 'nburn': 1000,
    #                 'niter': 1e+05,
    #                 'hyperpars': np.log(2)
    #             }
    #         }
    #     }
    # }
}
